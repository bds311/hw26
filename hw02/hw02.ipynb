# %%
# Initialize Otter
import otter
grader = otter.Notebook("hw02.ipynb")

# %% [markdown]
# # Homework 2: Pandas and Data Visualization
# # Due Friday 1/23 at 11:59pm

# %%
# Import me!
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# ## Point Breakdown
#
# Question | Sub | Points | Manual
# ----|----|----|----
# Q0|a|2|no|
# Q0|b|1|no|
# Q1|aa|2|no|
# Q1|ab|5|no|
# Q1|ac|5|no|
# Q1|b|10|no|
# Q1|c|15|yes|
# Q1|d|5|yes|
# Q1|e|15|yes|
# Q1|f|15|yes|
# Q1|g|5|yes|
# Q1|h|15|yes|
# Q1|i|5|yes|

# %% [markdown]
# ---
#
# ## Question 0: Warm Up - Creating a Pandas DataFrame
#
# We want to create a Pandas DataFrame from the following information:
#
# > The common name for *Yucca filamentosa* is Yucca, and it is not native to Oregon. Two plants that are native to Oregon are *Neottia cordata*, known as Heart-leaved twayblade, and *Festuca idahoensis*, known as Idaho fescue.
#
# ### Question 0a (2 pts):
# First make a dictionary from this information with three keys: `'latin_name'`, `'common_name'`, and `'oregon_native'`. The key `'oregon_native'` should have values `'yes'` or `'no'`.
#
# **Hint**: Copy/paste the names into your dictionary to avoid spelling issues. For the latin names, do not copy the asterisks.

# %% [markdown]
# #### Answer 0a

# %%
flora_dict = ...

# %%
grader.check("q0a")

# %% [markdown]
# ### Question 0b (1 pt):
#
# Now convert `flora_dict` into a 3x3 Pandas DataFrame.

# %% [markdown]
# #### Answer 0b

# %%
flora_df = ...

# %%
grader.check("q0b")

# %% [markdown]
# ---
# ## Question 1:
#
# Bike sharing systems are a new generation of traditional bike rentals where the process of signing up, renting and returning is automated. We will be analyzing bike sharing data from Washington D.C. in 2011 and 2012.
#
# In this assignment, you will perform tasks to clean, visualize, and explore the bike sharing data.
#
# After completing this assignment, you should be comfortable with:
#
# * Wrangling data for analysis
# * Using exploratory data analysis to investigate the data
# * Making informative visualizations and controlling plot parameters
# * Grouping data with `groupby` and `agg`

# %% [markdown]
# ### Question 1aa (2pts)
# #### Loading Bike Sharing Data
#
# Read the csv file `bikeshare.txt` into your notebook as a Pandas dataframe named `bikeshare_raw`. The resulting dataframe will have a series of variable names (columns). Below is a description of each variable in original file.
#
# Variable       | Description
# -------------- | ------------------------------------------------------------------
# instant | record index
# datetime | date (string)
# season | 1. spring <br> 2. summer <br> 3. fall <br> 4. winter
# yr | year (0: 2011, 1: 2012)
# mnth | month ( 1 to 12)
# hr | hour (0 to 23)
# holiday | whether day is holiday or not
# weekday | day of the week
# workingday | if day is neither weekend nor holiday
# weathersit | 1. clear or partly cloudy <br> 2. mist and clouds <br> 3. light snow or rain <br> 4. heavy rain or snow
# temp | normalized temperature in Celsius (divided by 41)
# atemp | normalized "feels-like" temperature in Celsius (divided by 50)
# hum | normalized percent humidity (divided by 100)
# windspeed| normalized wind speed (divided by 67)
# casual | count of casual bike users
# registered | count of registered bike users
# cnt | count of total rental bikes including casual and registered

# %%
# Load data into a Pandas Data Frame...
bikeshare_raw = ...

# %%
grader.check("q1aa")

# %% [markdown]
# #### Take a look at the dataframe

# %%
bikeshare_raw.head()

# %% [markdown]
# ### Question 1ab (5pts)
# #### Making replacements
# The `replace` [method](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.replace.html) of Pandas dataframes allows us to use a dictionary to replace existing values with alternatives.
#
# Create a replacement dictionary and use it within the `.replace()` method to make the following changes to bikeshare_raw.
#
#  1. `weekday` numbers (0,1,2,3,4,5,6) to three-letter string labels (`Sun`, `Mon`, `Tue`, `Wed`, `Thu`, `Fri`, and `Sat`).
#
#  2. Change the `holiday` and `workingday` labels of  `1` and `0` to `yes` and `no` respectively.
#
# Assign your replacement dictionary to the variable `replacement_dict`.
# Don't edit bikeshare_raw in-place, instead assign the output dataframe to the variable `bikeshare`.

# %%
# Assign your replacement dictionary to the variable replacement_dict
replacement_dict = ...

# Use .replace() on bikeshare_raw (do not do this in-place)
# assign the output dataframe to the variable bikeshare
bikeshare = ...
bikeshare.head()

# %%
grader.check("q1ab")

# %% [markdown]
# ### Question 1ac (5 pts)
# #### Converting hourly rider data to daily counts
# The original dataset has entries at the hourly level. However, for initial analysis, daily statistics will be most useful. We can do this using the `groupby` method introduced in class.
#
# Use `groupby` to construct a Pandas Series named `mean_temp_by_day`. The values should be mean temperature for each unique date. The index should be the datetime value.

# %%
mean_temp_by_day = ...

# %%
grader.check("q1ac")

# %% [markdown]
# ### Question 1b (10 pts)
#
# Construct a DataFrame named `daily_counts` grouped by `datetime` with the following columns:
# * `casual`: total number of casual riders for each day
# * `registered`: total number of registered riders for each day
# * `workingday`: whether that day is a working day or not (`yes` or `no`)
# * `mean_temp` : average temperature across all hourly readings from the day
# * `max_temp` : maximum temperature from the day
# * `min_temp` : minimum temperature from the day
#
# Finally, `datetime` should end up as its own column, not as the index - use `reset_index` for making dates a column, not an index.
#
# **Hint**: Use `groupby` and `agg`. If you use the capability to do different aggregations by column, you can do this task with a single call to `groupby` and `agg`. For the `workingday` column we can take any of the values since we are grouping by the day, thus the value will be the same within each group. Take a look at the `'first'` or `'last'` aggregation functions.

# %%
# Use groupby() and agg() to create the dataframe `daily_counts`
daily_counts = ...

# Reset the index of your daily_counts dataframe 
daily_counts = daily_counts.reset_index()

# %%
daily_counts.head()

# %%
grader.check("q1b")

# %% [markdown]
# ### Question 1c (15pts)
# #### Exploratory plotting of casual and registered ridership over time
# Make a scatter plot of daily casual and registered ridership over time that adheres to the following specifications:
#
#    1. Date is the horizontal axis. You can use the `datetime` column directly for these values. Some code is included to help clean up the label formatting.
#    2. Number of Daily Riders is on the vertical axis.
#
#    3. Include a legend, title, and axis labels.
#
# #### Notes on plot style:
# To copy our style in the example plot, use the following arguments in your ax1c.scatter() calls.
# - `facecolors='none'` (creates hollow points)
# - `edgecolors='c'`  (plot cyan edge color; you can assign color you want for distinct points)
#
# Your plot should look something like this:
#
# <img src="casual_and_registered_riders_daily.png">
#
# *This question will be manually graded. The checks below are there to make sure your plot has all of the required elements*

# %% [markdown]
# <!-- BEGIN QUESTION -->

# %%
# This code creates your figure and axis
fig,ax1c=plt.subplots(figsize=(8,8))

# Add elements to ax1c e.x. ax1c.scatter(...)
...

# This code formats your x-tick labels
plt.xticks(np.arange(0,len(daily_counts), 60), rotation = 45)
fig.autofmt_xdate()

# %%
grader.check("q1c")

# %% [markdown]
# <!-- END QUESTION -->
#
# ### Question 1d (5pts)
# - What does the above scatter plot suggest about possible seasonal trends in casual and registered ridership?
# - Apart from seasonal trends, what other sources of variability might contribute to daily differences in casual and registered ridership?
# - What does the plot tell us about the relative numbers of casual and registered riders?

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# ### Question 1e (15 pts)
# Make a scatter plot of registered riders vs casual riders for each day, following these specifications:
#
# 1. x axis is the # of casual riders
# 2. y axis is the # of registered riders
# 3. Set the aspect ratio of the plot to 1 so that the horizontal and vertical axes have the same scale.
# 4. Add a line with slope of 1 and intercept 0,  which corresponds to casual and registered ridership being equal.
# 5. Include axis labels and a title.
#
# **Hint**: The `axis` method for setting aspect is `set_aspect(...)` [(documentation)](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.set_aspect.html).
#
# Your plot should look something like this:
#
# <img src="casual_vs_registered_ridership_compared_1.png">
#
# *This question will be manually graded. The checks below are there to make sure your plot has all of the required elements*

# %% [markdown]
# <!-- BEGIN QUESTION -->

# %%
# This creates a new figure and sets its size
fig, ax1e = plt.subplots(figsize=(8,8))

# Add elements to ax1e e.x. ax1e.scatter(...)
...

# %%
grader.check("q1e")

# %% [markdown]
# <!-- END QUESTION -->
#
# ### Extra Question (0 pts)
# Are there certain days with more casual ridership than registered? <br>
# You can read this off the graph rather than perform analysis. How many days are there?

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# ### Question 1f (15 pts)
# Modify the above scatter plot so that the points plotted are divided into two colors. One color should denote working days (values of `workingday` with value `'yes'`) and another color denotes non-working days (weekends and holidays; values of `workingday` with value `'no'`). </br>
#
# Add a legend, title, axis labels, and a unit line (with slope 1 that goes through origin).
#
# Your plot should look something like this:
#
# <img src="casual_vs_registered_ridership_compared_2.png">
#
# *This question will be manually graded. The checks below are there to make sure your plot has all of the required elements*

# %% [markdown]
# ### Answer 1f

# %% [markdown]
# <!-- BEGIN QUESTION -->

# %%
# This creates a new figure and sets its size
fig, ax1f = plt.subplots(figsize=(8,8))

# Add elements to ax1f e.x. ax1f.scatter(...)
...

# %%
grader.check("q1f")

# %% [markdown]
# <!-- END QUESTION -->
#
# ### Question 1g (5 pts)
# On days with higher numbers of casual riders, do there also seem to be higher amounts of registered riders?<br>
# Does the value of `working day` seem to explain the ratio between casual and registered riders for that day? Explain.  <br>

# %% [markdown]
# ### Answer 1g:

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# ### Question 1h (15 pts)
# #### Testing the influence of temperature on casual and registered ridership
# Make a scatter plot that shows the relationship between daily mean temperature and casual ridership on working days and nonworking days. Plot individual days as scatter points, with `daily mean temperature` represented on the horizontal axis and `casual ridership` on the vertical axis. Make `working` and `nonworking` days separate colors to differentiate them.</br>
#
# Add legend, title, and axis labels
#
# Your plot should look something like this:
#
# <img src="casual_ridership_vs_mean_temp.png">
#
# *This question will be manually graded. The checks below are there to make sure your plot has all of the required elements*

# %% [markdown]
# ### Answer 1h

# %% [markdown]
# <!-- BEGIN QUESTION -->

# %%
# This creates a new figure and sets its size
fig, ax1h = plt.subplots(figsize=(8,8))

# Add elements to ax1h e.x. ax1h.scatter(...)
...

# %%
grader.check("q1h")

# %% [markdown]
# <!-- END QUESTION -->
#
# ### Question 1i (5 pts)
#
# Please answer each of the following questions in the space allowed below:
# 1. Does casual ridership tend to be higher on working or non-working days?
# 2. Broadly speaking, regardless of whether it is a working day, does the amount of casual ridership seem dependent on mean-temperature? How so?
# 3. Is the difference in casual ridership between working and non-working days higher on warmer or colder days?

# %% [markdown]
# ### Answer 1i

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# ## Submission
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will generate a zip file for you to submit. **Please save before exporting!**
#
# Save your notebook and then run the last cell. Download the generated zip file and upload it to Gradescope.

# %%
# Save your notebook first, then run this cell to export your submission.
grader.export(pdf=False, run_tests=True)
